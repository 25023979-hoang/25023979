# %% [markdown]
# bai 1

# %%
s = int(input ('nhap so nguyen: '))
sx2 =  s * 2
print (f'so gap doi cua {s} la : {sx2}')
# Out:
# so gap doi cua 7 la : 14

# %% [markdown]
# bai 2

# %%
cd = int(input('nhap chieu dai a :'))
cr = int(input('nhap chieu rong b :'))
dt = cd * cr
dtht = 3.14 * cr/2 * cr/2
dttc = dt - dtht
x = round(dttc,2)
print(f'dien tich trong cay la: {x}')
# Out:
# dien tich trong cay la: 30.38

# %% [markdown]
# bai 3

# %%
chu = input('nhap chu cai: ')
if chu.islower():
    chuhoa = chu.upper()
    print (chuhoa)
else:
    chuthg = chu.lower()
    print (chuthg)
# Out:
# B

# %% [markdown]
# bai 4

# %%
c = input('nhap ki tu: ')
if c.isalpha():
    print(f' {c} là kí tu alphabet')
else:
    print(f' {c} không phải là kí tự alphabet')
# Out:
#  9 không phải là kí tự alphabet

# %% [markdown]
# bai 5

# %%
chu = input('nhap mot chu cai: ')
if chu.isupper():
    if chu == 'A':
        print ( 'chu cai lien truoc la : z')
    else:
        chuthg = chu.lower()
        chulientruoc = chr(ord(chuthg) - 1)
        print(f'chu cai lien truoc la: {chulientruoc}')
else:
    print ('nhap chu cai in hoa'.upper())
# Out:
# chu cai lien truoc la: a

# %% [markdown]
# bai 6

# %%
a = int(input('nhap so a: '))
b = int(input('nhap so b: '))
c = int(input('nhap so c: '))
if a + b > c and a + c > b and b + c > a:
    print ('day la tam giac')
    p = (a+b+c)/2
    import math
    dientich = math.sqrt(p*(p-a)*(p-b)*(p-c))
    print(f'dien tich cua tam giac la {dientich:.1f}')
else:
    print('day khong phai hinh tam giac')
# Out:
# day la tam giac
# dien tich cua tam giac la 6.0

# %% [markdown]
# bai 7

# %%
a=input('nhap chuoi ki tu: ')
if len(a) >=20:
    chuthu5= a[4]
    chuthu9= a[8]
    print(f'ki tu 5 cua chuoi la: {chuthu5}')
    print(f'ki tu 9 cua chuoi la: {chuthu9}')
else:
    print('chuoi ki tu co do dai duoi 20')
# Out:
# ki tu 5 cua chuoi la: v
# ki tu 9 cua chuoi la: a

# %% [markdown]
# bai 8

# %%
ten=input('Ten chu ho: ')
truoc= int(input('Chi so thang truoc: '))
nay= int(input('Chi so thang nay: '))
so_dien=nay-truoc
tien_dien=0
if so_dien <= 50:
    tien_dien = so_dien * 1984
elif so_dien <= 100:
    tien_dien = 50 * 1984 + (so_dien - 50) * 2050
elif so_dien <= 200:
    tien_dien = 50 * 1984 + 50 * 2050 + (so_dien - 100) * 2380
elif so_dien <= 300:
    tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + (so_dien - 200) * 2998
elif so_dien <= 400:
    tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (so_dien - 300) * 3350
else:
    tien_dien = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (so_dien - 400) * 3460
tong=tien_dien*1.08
print(f'Ho va ten: {ten} \nTien phai tra la: {tong:.0f}')
# Out:
# Ho va ten: nguyen nhat tien
# Tien phai tra la: 120420
