# %% [markdown]
# bai 1

# %%
dai=float(input('nhap chieu dai cua hinh chu nhat: '))
rong=float(input('nhap chieu rong cua hinh chu nhat: '))
if dai != rong:
    dientich=dai*rong
    chuvi=(dai+rong)/2
    print(f'Dien tich hinh chu nhat la: {dientich:.1f}\nChu vi hinh chu nhat la: {chuvi:.1f}')
else:
    print('Day la hinh vuong, khong phai hinh chu nhat')
# Out:
# Dien tich hinh chu nhat la: 28.62
# Chu vi hinh chu nhat la: 5.35

# %% [markdown]
# bai 2

# %%
bk=float(input('nhap ban kinh hinh tron: '))
dientich=bk*bk*3.14
chuvi=2*bk*3.14
print(f'dien tich hinh tron la: {dientich}\nchu vi hinh tron la: {chuvi:.1f}')
# Out:
# dien tich hinh tron la: 78.5
# chu vi hinh tron la: 31.4

# %% [markdown]
# bai 3

# %%
import math
a = float(input('nhap so a: '))
b = float(input('nhap so b: '))
c = float(input('nhap so c: '))
if a + b > c and a + c > b and b + c > a:
    if a == b !=c or a==c!=b:
        print ('day la tam giac deu')
    elif a==b==c:
        print('day la tam giac deu')
    elif a==math.sqrt(b*b+c*c) or b==math.sqrt(a*a+c*c) or c==math.sqrt(b*b+a*a):
        print ('day la tam giac vuong')
    else:
        print('day la tam giac thuong')
    p = (a+b+c)/2
    dientich = math.sqrt(p*(p-a)*(p-b)*(p-c))
    chuvi= p*2
    print(f'dien tich cua tam giac la: {dientich:.1f}\nchu vi cua tam giac la: {chuvi:.1f}')
else:
    print('Khong la ba canh cua mot tam giac')
# Out:
# day la tam giac vuong
# dien tich cua tam giac la: 6.0
# chu vi cua tam giac la: 12.0

# %% [markdown]
# bai 4

# %%
a=float(input('nhap so a trong ax+b=0: '))
b=float(input('nhap so b trong ax+b=0: '))
if a!=0:
    x=(0-b)/a
    print(f'gia tri cua x la: {x}')
else:
    print('loi phep tinh, vui long nhap a khac 0')
# Out:
# syntax error

# %% [markdown]
# bai 5

# %%
a=float(input('nhap so a: '))
b=float(input('nhap so b: '))
c=float(input('nhap so b: '))
x=0
if a!=0:
    delta=b*b-4*a*c
    if delta < 0:
        print('phuong trinh vo nghiem')
    elif delta == 0:
        x=(0-b)/(2*a)
        print(f'phuong trinh co nghiem la {x}')
    else:
        x1=((0-b)+math.sqrt(delta))/(2*a)
        x2=((0-b)-math.sqrt(delta))/(2*a)
        print(f'phuong trinh co 2 nghiem:\nnghiem thu nhat: {x1}\nnghiem thu hai: {x2}')
else:
    print('loi phep tinh, vui long nhap a khac 0')
# Out:
# phuong trinh co 2 nghiem:
# nghiem thu nhat: 2.0
# nghiem thu hai: 0.3333333333333333

# %% [markdown]
# bai 6

# %%
a=float(input('nhap so a: '))
b=float(input('nhap so b: '))
c=float(input('nhap so c: '))
d=float(input('nhap so d: '))
if a>b and a>c and a>d:
    print(f'so lon nhat la: {a}')
elif b>a and b>c and b>d:
    print(f'so lon nhat la: {b}')
elif c>a and c>b and c>d:
    print(f'so lon nhat la: {c}')
else:
    print(f'so lon nhat la: {d}')
# Out:
# so lon nhat la: 8.0

# %% [markdown]
# bai 7

# %%
a=float(input('nhap so a: '))
b=float(input('nhap so b: '))
c=float(input('nhap so c: '))
d=float(input('nhap so d: '))
if a<b and a<c and a<d:
    print(f'so be nhat la: {a}')
elif b<a and b<c and b<d:
    print(f'so be nhat la: {b}')
elif c<a and c<b and c<d:
    print(f'so be nhat la: {c}')
else:
    print(f'so be nhat la: {d}')
# Out:
# so be nhat la: 2.0

# %% [markdown]
# bai 8

# %%
a=float(input('nhap so a: '))
b=float(input('nhap so b: '))
c=float(input('nhap so c: '))
d=float(input('nhap so d: '))
m=float(input('nhap so m: '))
n=float(input('nhap so n: '))
tile=a/c
d1=d*tile
n1=n*tile
y=(m-n1)/(b-d1)
x=(m-b*y)/a
print(f' gia tri cua x la: {x}\ngia tri cua y la: {y}')
# Out:
#  gia tri cua x la: 1.0
# gia tri cua y la: 2.0

# %% [markdown]
# bai 9

# %%
import math
x=float(input('nhap thoi gian (giay): '))
gio=0
phut=0
giay=0
if x<60:
    print(f'{x} giay')
elif 3600>x>=60:
    phut= x//60
    giay= x-phut*60
    print(f'{phut} gio\n{giay} giay')
else:
    gio = x // 3600
    phut = (x % 3600) // 60
    giay = x % 60
    print(f'{gio} gio\n{phut} phut\n{giay} giay')
# Out:
# 24826.0 gio
# 39.0 phut
# 42.5 giay

# %% [markdown]
# bai 10

# %%
a=int(input('toa do a cua tam: '))
b=int(input('toa do b cua tam: '))
bk=int(input('ban kinh duong tron: '))
x=int(input('toa do x cua A: '))
y=int(input('toa do y cua A: '))
if (x-a)**2 + (y-b)**2 <= bk **2:
    print('M thuoc duong tron')
else:
    print('M khong thuoc duong tron')

# %% [markdown]
# bai 11

# %%
x=float(input('nhap x: '))
y=float(input('nhap y: '))
luythua= x**y
print (f'x luy thua y la: {luythua}')
# Out:
# x luy thua y la: 0.125
